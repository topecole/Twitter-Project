# %%
#@title
#package for social network scraping
# !pip install -q snscrape transformers matplotlib wordcloud

# %%
pip install tweepy
# Out:
# ...
#      ---------------------------------------- 0.0/102.8 kB ? eta -:--:--
#      ---------------------------------------- 102.8/102.8 kB ? eta 0:00:00
# ...
#      ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#      -------------------------------------- 151.7/151.7 kB 9.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#@title
# Import libraries
import pandas as pd
import tweepy
import warnings
warnings.filterwarnings('ignore')
import snscrape.modules.twitter as sntwitter
import requests

# %%
# Query by Advanced text search
Topic = input('Search Criteria (Use OR where multiple words can be used):')
Location = input('Location:')
StDate = input('Start Date (YYYY-MM-DD):')
EnDate = input('End Date (YYYY-MM-DD):')
maxTweets = int(input('Maximum No of Tweets:'))

# Creating list to append tweet data to
tweets_list = []

query = '('+Topic+')'+' near:"'+ Location + '" lang:en until:'+EnDate+ ' since:'+StDate + ' -filter:links -filter:retweet'

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper(query).get_items()):
    if i>maxTweets:
        break
    tweets_list.append([tweet.date, tweet.id, tweet.rawContent, tweet.user.username, tweet.retweetCount, tweet.viewCount])

# Creating a dataframe from the tweets list above
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'Retweet', 'Views'])

#tweets_df['Datetime'] = tweets_df['Datetime'].dt.tz_localize(None)

# Display first 5 entries from dataframe
tweets_df
# Out:
# Search Criteria (Use OR where multiple words can be used): Strike
# Location: London
# Start Date (YYYY-MM-DD): 2023-01-01
# End Date (YYYY-MM-DD): 2023-03-05
# Maximum No of Tweets: 100
#                      Datetime             Tweet Id  \
# 0   2023-03-04 22:22:38+00:00  1632144546829139968
# 1   2023-03-04 19:53:43+00:00  1632107071628877825
# 2   2023-03-04 19:33:28+00:00  1632101976245673984
# 3   2023-03-04 19:30:46+00:00  1632101294306459649
# 4   2023-03-04 17:10:41+00:00  1632066041705791489
# ..                        ...                  ...
# 96  2023-02-23 21:22:40+00:00  1628867965994119171
# 97  2023-02-23 15:23:35+00:00  1628777600062566401
# 98  2023-02-23 14:29:58+00:00  1628764104046309378
# 99  2023-02-23 13:27:11+00:00  1628748305910956032
# 100 2023-02-23 12:27:57+00:00  1628733399941750787
#
#                                                   Text         Username  \
# 0             Is a strike on #Iran on the horizon? ☢️🚀       EihabNakib
# ...
